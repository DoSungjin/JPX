# %%
import jpx_tokyo_market_prediction
from sklearn.tree import DecisionTreeRegressor
from tqdm.notebook import tqdm
import optuna
optuna.logging.set_verbosity(optuna.logging.CRITICAL)
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import gc
import os
import matplotlib.pyplot as plt
from pprint import pprint
import seaborn as sns
from matplotlib import cm
from IPython.core.display import display, HTML
from tqdm import tqdm
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error
from tqdm.notebook import tqdm
from itertools import combinations, product
from functools import partial
from multiprocessing import Pool, Manager, cpu_count
from IPython.display import display_html
sns.set_context("notebook")

import warnings
warnings.filterwarnings("ignore")
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
def prep_prices(price):
    
    from decimal import ROUND_HALF_UP, Decimal
    
    pcols = ["Open","High","Low","Close"]

    price.ExpectedDividend.fillna(0,inplace=True)
    
    def qround(x):
        return float(Decimal(str(x)).quantize(Decimal('0.1'), rounding=ROUND_HALF_UP))
    
    def adjust_prices(df):
        df = df.sort_values("Date", ascending=False)
        df.loc[:, "CumAdjust"] = df["AdjustmentFactor"].cumprod()

        # generate adjusted prices
        for p in pcols:     
            df.loc[:, p] = (df["CumAdjust"] * df[p]).apply(qround)
        df.loc[:, "Volume"] = df["Volume"] / df["CumAdjust"]
        df.ffill(inplace=True)
        df.bfill(inplace=True)
        
        # generate and fill Targets
        #df.loc[:, "Target"] = df.Close.pct_change().shift(-2).fillna(df.Target).fillna(0)
        df.Target.fillna(0,inplace=True)

        return df

    # generate Adjusted
    price = price.sort_values(["SecuritiesCode", "Date"])
    price = price.groupby("SecuritiesCode").apply(adjust_prices).reset_index(drop=True)
    price = price.sort_values("RowId")
    return price

# %%
options = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/train_files/options.csv")
options.head(3)
# Out:
#              DateCode        Date  OptionsCode  WholeDayOpen  WholeDayHigh  \
# 0  20170104_132010018  2017-01-04    132010018         650.0         650.0
# 1  20170104_132010118  2017-01-04    132010118           0.0           0.0
# 2  20170104_132010218  2017-01-04    132010218           0.0           0.0
#
#    WholeDayLow  WholeDayClose NightSessionOpen NightSessionHigh  \
# 0        480.0          480.0           0.0000           0.0000
# 1          0.0            0.0           0.0000           0.0000
# 2          0.0            0.0           0.0000           0.0000
#
#   NightSessionLow  ... Putcall  LastTradingDay  SpecialQuotationDay  \
# 0          0.0000  ...       1        20170112             20170113
# 1          0.0000  ...       1        20170112             20170113
# 2          0.0000  ...       1        20170112             20170113
#
#    SettlementPrice  TheoreticalPrice  BaseVolatility  ImpliedVolatility  \
# 0            480.0          478.4587         17.4736            17.5865
# 1            575.0          571.1385         17.4736            16.5000
# 2            680.0          677.3710         17.4736            15.8644
#
#    InterestRate  DividendRate  Dividend
# 0        0.0091           0.0       0.0
# 1        0.0091           0.0       0.0
# 2        0.0091           0.0       0.0
#
# [3 rows x 31 columns]

# %%
stock_fin_spec = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/data_specifications/stock_fin_spec.csv")
stock_fin_spec
# Out:
#                                                Column  \
# 0                                    DisclosureNumber
# 1                                            DateCode
# 2                                                Date
# 3                                      SecuritiesCode
# 4                                       DisclosedDate
# 5                                       DisclosedTime
# 6                                   DisclosedUnixTime
# 7                                      TypeOfDocument
# 8                                CurrentPeriodEndDate
# 9                                 TypeOfCurrentPeriod
# 10                         CurrentFiscalYearStartDate
# 11                           CurrentFiscalYearEndDate
# 12                                           NetSales
# 13                                    OperatingProfit
# 14                                     OrdinaryProfit
# 15                                             Profit
# 16                                   EarningsPerShare
# 17                                        TotalAssets
# 18                                             Equity
# 19                                 EquityToAssetRatio
# 20                                  BookValuePerShare
# 21                   ResultDividendPerShare1stQuarter
# 22                   ResultDividendPerShare2ndQuarter
# 23                   ResultDividendPerShare3rdQuarter
# 24                ResultDividendPerShareFiscalYearEnd
# 25                       ResultDividendPerShareAnnual
# 26                 ForecastDividendPerShare1stQuarter
# 27                 ForecastDividendPerShare2ndQuarter
# 28                 ForecastDividendPerShare3rdQuarter
# 29              ForecastDividendPerShareFiscalYearEnd
# 30                     ForecastDividendPerShareAnnual
# 31                                   ForecastNetSales
# 32                            ForecastOperatingProfit
# 33                             ForecastOrdinaryProfit
# 34                                     ForecastProfit
# 35                           ForecastEarningsPerShare
# 36  ApplyingOfSpecificAccountingOfTheQuarterlyFina...
# 37                      MaterialChangesInSubsidiaries
# 38        ChangesBasedOnRevisionsOfAccountingStandard
# 39  ChangesOtherThanOnesBasedOnRevisionsOfAccounti...
# 40                       ChangesInAccountingEstimates
# 41                           RetrospectiveRestatement
# 42  NumberOfIssuedAndOutstandingSharesAtTheEndOfFi...
# 43          NumberOfTreasuryStockAtTheEndOfFiscalYear
# 44                              AverageNumberOfShares
#
#                              Sample value     Type  \
# 0                          20161025419878    Int64
# 1                           20170106_7888   string
# 2                      2017-01-06 0:00:00     date
# 3                                    7888    Int64
# 4                      2017-01-06 0:00:00     date
# 5                                15:30:00     time
# 6                              1483684200    Int64
# 7   2QFinancialStatements_Consolidated_JP   string
# 8                              2016-11-30     date
# 9                                      2Q     date
# 10                             2016-06-01     date
# 11                             2017-05-31     date
# 12                            27528000000    Int64
# 13                             1076000000    Int64
# 14                             1042000000    Int64
# 15                              796000000    Int64
# 16                                  31.25    float
# 17                            42651000000    Int64
# 18                            14220000000    Int64
# 19                                  0.326    float
# 20                                 545.78    float
# 21                                      －    float
# 22                                      5    float
# 23                                    NaN    float
# 24                                    NaN    float
# 25                                    NaN    float
# 26                                    NaN    float
# 27                                    NaN    float
# 28                                      －    float
# 29                                      5    float
# 30                                     10    float
# 31                            56000000000    Int64
# 32                             2400000000    Int64
# 33                             2000000000    Int64
# 34                             1300000000    Int64
# 35                                  51.01    float
# 36                                    NaN  boolean
# 37                                  FALSE  boolean
# 38                                  FALSE  boolean
# 39                                  FALSE  boolean
# 40                                  FALSE  boolean
# 41                                  FALSE  boolean
# 42                               25688569    Int64
# 43                                 203627    Int64
# 44                               25485430    Int64
#
#                                              Addendum  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   [Normal] 1Q (1st Quarter), 2Q (2nd Quarter), 3...
# 10                                         YYYY-MM-DD
# 11                                         YYYY-MM-DD
# 12                                  Cumulated from 1Q
# 13                                  Cumulated from 1Q
# 14                                  Cumulated from 1Q
# 15                                  Cumulated from 1Q
# 16      Cumulated from 1Q (round to 2 decimal places)
# 17    Actual value for the current accounting period.
# 18    Actual value for the current accounting period.
# 19  Actual value for the current accounting period...
# 20    Actual value for the current accounting period.
# 21  Actual value for the past or current accountin...
# 22  Actual value for the past or current accountin...
# 23  Actual value for the past or current accountin...
# 24  Actual value for the past or current accountin...
# 25          Actual value for the current fiscal year.
# 26  Future expectations.\n\n[Note] Blank if it is ...
# 27                               Future expectations.
# 28                               Future expectations.
# 29                               Future expectations.
# 30                               Future expectations.
# 31           Future expectations. (Cumulated from 1Q)
# 32           Future expectations. (Cumulated from 1Q)
# 33           Future expectations. (Cumulated from 1Q)
# 34                               Future expectations.
# 35                               Future expectations.
# 36                              TRUE, FALSE, or blank
# 37                              TRUE, FALSE, or blank
# 38                              TRUE, FALSE, or blank
# 39                              TRUE, FALSE, or blank
# 40                              TRUE, FALSE, or blank
# 41                              TRUE, FALSE, or blank
# 42    Actual value for the current accounting period.
# 43    Actual value for the current accounting period.
# 44    Actual value for the current accounting period.
#
#                                               Remarks
# 0                 Unique ID for disclosure documents.
# 1   combination of TradeDate and LocalCode (this i...
# 2   Trade date. This column is used to align with ...
# 3                               Local Securities Code
# 4               Date on which the document disclosed.
# 5               Time on which the document disclosed.
# 6   Unix time of the datetime on which the documen...
# 7                      Document type indicated by ID.
# 8          End date of the current accounting period.
# 9   Type of the current accounting period.\n\n[Not...
# 10             Start date of the current fiscal year.
# 11               End date of the current fiscal year.
# 12  Gross sales (the total amount of sales a compa...
# 13  Net sales minus operating expenses (cost of go...
# 14  [JP Standard] Operating income plus non-operat...
# 15  Income before income taxes (ordinary income pl...
# 16  Earnings Per Share (EPS), which is the net inc...
# 17  Total of the asset, including current assets (...
# 18  Total assets minus total liabilities (total of...
# 19                     Equity divided by total assets
# 20  Book-value Per Share (BPS), which is the equit...
# 21  Dividend amount at the end of the 1st quarter....
# 22  Dividend amount at the end of the 2nd quarter....
# 23  Dividend amount at the end of the 3rd quarter....
# 24  Dividend amount at the end of the 4th quarter....
# 25                Total annual dividend amount. [yen]
# 26  Expected dividend amount at the end of the 1st...
# 27  Expected dividend amount at the end of the 2nd...
# 28  Expected dividend amount at the end of the 3rd...
# 29  Expected dividend amount at the end of the 4th...
# 30       Expected total annual dividend amount. [yen]
# 31                    Expected annual net sales [yen]
# 32             Expected annual operating income [yen]
# 33              Expected annual ordinary income [yen]
# 34                   Expected annual net income [yen]
# 35           Expected annual earnings per share [yen]
# 36  Applying of accounting methods specific to the...
# 37  Changes in significant subsidiaries during the...
# 38  Changes in accounting policies associated with...
# 39  Changes in accounting policies based on justif...
# 40  Changes in accounting estimates. (changes in a...
# 41  The reflection, in consolidated financial stat...
# 42  Number of issued shares at the end of the peri...
# 43  Number of treasury shares at the end of the pe...
# 44  Average number of shares between the start dat...

# %%
stock_list = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/stock_list.csv")
stock_list.head(3)
# Out:
#    SecuritiesCode  EffectiveDate                                   Name  \
# 0            1301       20211230                       KYOKUYO CO.,LTD.
# 1            1305       20211230                        Daiwa ETF-TOPIX
# 2            1306       20211230  NEXT FUNDS TOPIX Exchange Traded Fund
#
#            Section/Products NewMarketSegment 33SectorCode  \
# 0  First Section (Domestic)     Prime Market           50
# 1                ETFs/ ETNs              NaN            -
# 2                ETFs/ ETNs              NaN            -
#
#                         33SectorName 17SectorCode 17SectorName  \
# 0  Fishery, Agriculture and Forestry            1       FOODS
# 1                                  -            -            -
# 2                                  -            -            -
#
#   NewIndexSeriesSizeCode NewIndexSeriesSize   TradeDate   Close  IssuedShares  \
# 0                      7      TOPIX Small 2  20211230.0  3080.0  1.092828e+07
# 1                      -                  -  20211230.0  2097.0  3.634636e+09
# 2                      -                  -  20211230.0  2073.5  7.917718e+09
#
#    MarketCapitalization  Universe0
# 0          3.365911e+10       True
# 1          7.621831e+12      False
# 2          1.641739e+13      False

# %%
options_spec = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/data_specifications/options_spec.csv")
options_spec
# Out:
#                  Column        Sample value    Type  Addendum  \
# 0              DateCode  20170104_144122718  string       NaN
# 1                  Date  2017-01-04 0:00:00    date       NaN
# 2           OptionsCode           144122718  string       NaN
# 3          WholeDayOpen                   0   float       NaN
# 4          WholeDayHigh                   0   float       NaN
# 5           WholeDayLow                   0   float       NaN
# 6         WholeDayClose                   0   float       NaN
# 7      NightSessionOpen                   0   float       NaN
# 8      NightSessionHigh                   0   float       NaN
# 9       NightSessionLow                   0   float       NaN
# 10    NightSessionClose                   0   float       NaN
# 11       DaySessionOpen                   0   float       NaN
# 12       DaySessionHigh                   0   float       NaN
# 13        DaySessionLow                   0   float       NaN
# 14      DaySessionClose                   0   float       NaN
# 15        TradingVolume                   0   Int64       NaN
# 16         OpenInterest                   0   Int64       NaN
# 17         TradingValue                   0   Int64       NaN
# 18        ContractMonth              201912   Int64       NaN
# 19          StrikePrice               12750   float       NaN
# 20       WholeDayVolume                   0   Int64       NaN
# 21              Putcall                   2   Int64       NaN
# 22       LastTradingDay            20191212    date       NaN
# 23  SpecialQuotationDay            20191213    date       NaN
# 24      SettlementPrice                6680   float       NaN
# 25     TheoreticalPrice              6679.7   float       NaN
# 26       BaseVolatility             17.4736   float       NaN
# 27    ImpliedVolatility             26.0651   float       NaN
# 28         InterestRate              0.1282   float       NaN
# 29         DividendRate              1.6817   float       NaN
# 30             Dividend            0.00E+00   float       NaN
#
#                                               Remarks
# 0                  Unique ID for option price records
# 1                                 Trade date and time
# 2   Local Securities Code (link to https://www.jpx...
# 3                 Opening Price for Whole Trading Day
# 4                    High Price for Whole Trading Day
# 5                     Low Price for Whole Trading Day
# 6                 Closing Price for Whole Trading Day
# 7                     Opening Price for Night Session
# 8                        High Price for Night Session
# 9                         Low Price for Night Session
# 10                    Closing Price for Night Session
# 11                      Opening Price for Day Session
# 12                         High Price for Day Session
# 13                          Low Price for Day Session
# 14                      Closing Price for Day Session
# 15  DaySessionVolume + NightSessionVolume + J-NET ...
# 16  Open interest of the product/contract for the ...
# 17  Trading value of the product/contract for the ...
# 18         Cotract year-month of the product/contract
# 19                 Exercise Price of product/contract
# 20              DaySessionVolume + NightSessionVolume
# 21                                    Put:1\r\nCall:2
# 22                                   Last Trading Day
# 23   The day when the Special Quotation is calculated
# 24                                   Settlement price
# 25  The theoretical price at the end of a day session
# 26  The volatility at the time of calculating the ...
# 27                                 Implied Volatility
# 28                      Interest rate for calculation
# 29                                    Dividendv yeild
# 30                                           Devidend

# %%
stock_list_spec = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/data_specifications/stock_list_spec.csv")
stock_list_spec
# Out:
#                     Column                       Sample value     Type  \
# 0           SecuritiesCode                               1301    Int64
# 1            EffectiveDate                           20211230     date
# 2                     Name                   KYOKUYO CO.,LTD.   string
# 3         Section/Products           First Section (Domestic)   string
# 4         NewMarketSegment                       Prime Market   string
# 5             33SectorCode                                 50    Int64
# 6             33SectorName  Fishery, Agriculture and Forestry   string
# 7             17SectorCode                                  1    Int64
# 8             17SectorName                              FOODS   string
# 9   NewIndexSeriesSizeCode                                  7    Int64
# 10      NewIndexSeriesSize                      TOPIX Small 2   string
# 11               TradeDate                           20211230     date
# 12                   Close                               3080    float
# 13            IssuedShares                           1.09E+07    float
# 14    MarketCapitalization                        33659111640    float
# 15               Universe0                               TRUE  boolean
#
#     Addendum                                            Remarks
# 0        NaN                              Local Securities Code
# 1        NaN                                 the effective date
# 2        NaN                                   Name of security
# 3        NaN                                    Section/Product
# 4        NaN  New market segment effective from 2022-04-04 (...
# 5        NaN  33 Sector Name\n\nref. https://www.jpx.co.jp/e...
# 6        NaN  33 Sector Name\n\nref. https://www.jpx.co.jp/e...
# 7        NaN  17 Sector Code\nref. https://www.jpx.co.jp/eng...
# 8        NaN  17 Sector Name\nref. https://www.jpx.co.jp/eng...
# 9        NaN  TOPIX New Index Series code\n\nref. https://ww...
# 10       NaN  TOPIX New Index Series Name\n\nref. https://ww...
# 11       NaN       Trade date to calculate MarketCapitalization
# 12       NaN      Close price to calculate MarketCapitalization
# 13       NaN                                      Issued shares
# 14       NaN                Market capitalization on Dec 3 2021
# 15       NaN  a flag of prediction target universe (top 2000...

# %%
financials = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/train_files/financials.csv")
financials.head(3)
# Out:
#    DisclosureNumber       DateCode        Date  SecuritiesCode DisclosedDate  \
# 0      2.016121e+13  20170104_2753  2017-01-04          2753.0    2017-01-04
# 1      2.017010e+13  20170104_3353  2017-01-04          3353.0    2017-01-04
# 2      2.016123e+13  20170104_4575  2017-01-04          4575.0    2017-01-04
#
#   DisclosedTime  DisclosedUnixTime                         TypeOfDocument  \
# 0      07:30:00       1.483483e+09  3QFinancialStatements_Consolidated_JP
# 1      15:00:00       1.483510e+09  3QFinancialStatements_Consolidated_JP
# 2      12:00:00       1.483499e+09                       ForecastRevision
#
#   CurrentPeriodEndDate TypeOfCurrentPeriod  ... ForecastEarningsPerShare  \
# 0           2016-12-31                  3Q  ...                   319.76
# 1           2016-11-30                  3Q  ...                   485.36
# 2           2016-12-31                  2Q  ...                   -93.11
#
#   ApplyingOfSpecificAccountingOfTheQuarterlyFinancialStatements  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   MaterialChangesInSubsidiaries ChangesBasedOnRevisionsOfAccountingStandard  \
# 0                         False                                        True
# 1                         False                                        True
# 2                           NaN                                         NaN
#
#   ChangesOtherThanOnesBasedOnRevisionsOfAccountingStandard  \
# 0                                              False
# 1                                              False
# 2                                                NaN
#
#   ChangesInAccountingEstimates RetrospectiveRestatement  \
# 0                        False                    False
# 1                        False                    False
# 2                          NaN                      NaN
#
#   NumberOfIssuedAndOutstandingSharesAtTheEndOfFiscalYearIncludingTreasuryStock  \
# 0                                          6848800.0
# 1                                          2035000.0
# 2                                                NaN
#
#   NumberOfTreasuryStockAtTheEndOfFiscalYear AverageNumberOfShares
# 0                                         －             6848800.0
# 1                                    118917             1916083.0
# 2                                       NaN                   NaN
#
# [3 rows x 45 columns]

# %%
# %%time
# Loading Stock Prices
path = "../input/jpx-tokyo-stock-exchange-prediction/"

df_train = pd.read_csv(f"{path}train_files/stock_prices.csv", parse_dates=["Date"])
df_train = df_train[df_train.Date>"2020-10-02"] #Targets not Nulls and 2000 secutities data
df_train = prep_prices(df_train)

df_test = pd.read_csv(f"{path}supplemental_files/stock_prices.csv", parse_dates=["Date"])
df_test = prep_prices(df_test)
# Out:
# CPU times: user 47 s, sys: 842 ms, total: 47.8 s
# Wall time: 47.8 s

# %%
def fill_nans(prices):
    prices.set_index(["SecuritiesCode", "Date"], inplace=True)
    prices.ExpectedDividend.fillna(0,inplace=True)
    prices.ffill(inplace=True)
    prices.fillna(0,inplace=True)
    prices.reset_index(inplace=True)
    return prices
# ffill은 가장 많이 쓰는 방법으로 전기의 값을 쭉 채워주는 것.(이성적으로도 맞는 방법) -> 기본적으로 ffill 적용 후에 
# parameter 조정할 때 혹은 feature을 추가 시킬 때, 보간법(선형, 비선형 등)을 적용한다.

# %%
# %%time


df_train= fill_nans(df_train)
# Out:
# CPU times: user 204 ms, sys: 28 µs, total: 204 ms
# Wall time: 203 ms

# %%
# create new dataframe with just closing price for each stock
df = df_train.pivot(index='Date', columns='SecuritiesCode', values='Close')
df
# Out:
# SecuritiesCode    1301   1332    1333    1375    1376    1377    1379    1381  \
# Date
# 2020-10-05      2819.0  453.0  2412.0  2062.0  1615.0  3775.0  2238.0  3330.0
# 2020-10-06      2824.0  450.0  2398.0  2044.0  1588.0  3785.0  2236.0  3355.0
# 2020-10-07      2780.0  446.0  2345.0  2035.0  1541.0  3730.0  2243.0  3300.0
# 2020-10-08      2786.0  443.0  2345.0  2035.0  1502.0  3800.0  2254.0  3250.0
# 2020-10-09      2799.0  436.0  2336.0  2099.0  1510.0  3745.0  2244.0  3300.0
# ...                ...    ...     ...     ...     ...     ...     ...     ...
# 2021-11-29      2951.0  567.0  2269.0  1248.0  1381.0  3125.0  1889.0  3160.0
# 2021-11-30      2900.0  573.0  2277.0  1217.0  1348.0  3125.0  1842.0  3135.0
# 2021-12-01      2911.0  574.0  2299.0  1231.0  1353.0  3135.0  1889.0  3185.0
# 2021-12-02      2933.0  573.0  2303.0  1212.0  1327.0  3110.0  1867.0  3150.0
# 2021-12-03      2982.0  585.0  2358.0  1235.0  1332.0  3170.0  1891.0  3200.0
#
# SecuritiesCode    1407    1413  ...    9982     9983    9984    9987    9989  \
# Date                            ...
# 2020-10-05      2133.8  1978.0  ...  1799.0  66790.0  6750.0  3980.0  4010.0
# 2020-10-06      2203.1  1988.0  ...  1829.0  66700.0  6913.0  4060.0  3985.0
# 2020-10-07      2237.7  1990.0  ...  1868.0  66490.0  6955.0  3980.0  3940.0
# 2020-10-08      2330.8  1976.0  ...  1862.0  67290.0  7085.0  4025.0  4045.0
# 2020-10-09      2469.2  1989.0  ...  1711.0  69220.0  6997.0  4020.0  4080.0
# ...                ...     ...  ...     ...      ...     ...     ...     ...
# 2021-11-29      6430.0  2126.0  ...  1725.0  70500.0  6208.0  3070.0  3055.0
# 2021-11-30      6550.0  2118.0  ...  1690.0  67400.0  6030.0  3085.0  2989.0
# 2021-12-01      6290.0  2123.0  ...  1722.0  67080.0  5900.0  3090.0  2937.0
# 2021-12-02      6070.0  2112.0  ...  1680.0  67140.0  5599.0  3105.0  2947.0
# 2021-12-03      6190.0  2197.0  ...  1746.0  66650.0  5559.0  3175.0  3015.0
#
# SecuritiesCode   9990   9991    9993    9994   9997
# Date
# 2020-10-05      571.0  951.0  1794.0  2169.0  934.0
# 2020-10-06      573.0  952.0  1788.0  2185.0  943.0
# 2020-10-07      569.0  932.0  1808.0  2185.0  960.0
# 2020-10-08      568.0  944.0  1824.0  2195.0  953.0
# 2020-10-09      569.0  934.0  1840.0  2169.0  958.0
# ...               ...    ...     ...     ...    ...
# 2021-11-29      528.0  773.0  1680.0  2358.0  668.0
# 2021-11-30      520.0  768.0  1680.0  2328.0  667.0
# 2021-12-01      522.0  770.0  1671.0  2340.0  685.0
# 2021-12-02      507.0  778.0  1650.0  2362.0  684.0
# 2021-12-03      528.0  794.0  1645.0  2389.0  696.0
#
# [287 rows x 2000 columns]

# %%
from fbprophet import Prophet
from fbprophet.make_holidays import make_holidays_df

# %% [markdown]
# # **creat prophet prediction value(target)**

# %%
Code = df.columns[0]  
cols = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'SecuritiesCode', 'Target']
STOCK = df_train[df_train.SecuritiesCode==Code][cols].set_index("Date")
TEST = df_test[df_test.SecuritiesCode==Code].set_index("Date")

year_list = [2017, 2018, 2019, 2020, 2021, 2022, 2023]
holidays = make_holidays_df(year_list=year_list, country='JP')
fut = TEST[:]
d = 365 # days to plot
w = 3 # windows size

LDAYS = STOCK.tail(d)
fut = pd.concat([STOCK,TEST])
xd = (LDAYS.index).append(TEST.index)

fut['Cl_lr'] = fut.Close.rolling(window=w,closed="left").apply(lambda y: 
               np.poly1d(np.polyfit(np.array(range(w)),y,1))(w),raw=True)

fut['Cl2'] = fut.Close.rolling(window=2,closed="left").apply(lambda y: 
               np.poly1d(np.polyfit([0,1],y,1))(2),raw=True)

rho = np.corrcoef(fut.Close[-len(xd):],fut.Cl_lr[-len(xd):])
ph_df = fut[["Close","Cl_lr",'Cl2']][w:len(STOCK)].reset_index()
ph_df.rename(columns={'Close': 'y', 'Date': 'ds'}, inplace=True)

m = Prophet(holidays=holidays,
        daily_seasonality=False,
        changepoint_prior_scale=0.015)
m.add_seasonality(name='monthly', period=25.5, fourier_order=5)
m.add_regressor('Cl_lr')
m.add_regressor('Cl2')
m.fit(ph_df)
future_prices = m.make_future_dataframe(periods=175, freq='d')
future_prices = future_prices[future_prices.ds.dt.dayofweek < 5]
future_prices = future_prices.set_index("ds").join(fut[['Cl_lr','Cl2']][w:], how='left')

future_prices = future_prices.reset_index()   
forecast = m.predict(future_prices)
result = TEST[['Close']].join(forecast.set_index("ds"),how='left')
result=result[['yhat']]
result=result.rename(columns = {"yhat": str(df.columns[0])}, inplace=False)
prophet_result=pd.DataFrame(result)
prophet_result=prophet_result.reset_index()
prophet_result
# Out:
# Initial log joint probability = -2.26114
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1134.72   0.000341394       299.122           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1135.06   2.00406e-05       240.792           1           1      252
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      264       1135.26   1.01197e-09       220.213    0.002294      0.2388      334
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
#           Date         1301
# 0   2021-12-06  3039.315357
# 1   2021-12-07  2999.969707
# 2   2021-12-08  3090.926833
# 3   2021-12-09  3094.448575
# 4   2021-12-10  3098.764267
# ..         ...          ...
# 110 2022-05-23  3288.093367
# 111 2022-05-24  3315.788791
# 112 2022-05-25  3281.496079
# 113 2022-05-26  3275.915056
# 114 2022-05-27  3281.853464
#
# [115 rows x 2 columns]

# %%
for i in range(df.columns[1],2000):
    # Select Security Code
        Code = df.columns[i]  
        cols = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'SecuritiesCode', 'Target']
        STOCK = df_train[df_train.SecuritiesCode==Code][cols].set_index("Date")
        TEST = df_test[df_test.SecuritiesCode==Code].set_index("Date")

        year_list = [2017, 2018, 2019, 2020, 2021, 2022, 2023]
        holidays = make_holidays_df(year_list=year_list, country='JP')
        fut = TEST[:]
        d = 365 # days to plot
        w = 3 # windows size

        LDAYS = STOCK.tail(d)
        fut = pd.concat([STOCK,TEST])
        xd = (LDAYS.index).append(TEST.index)

        fut['Cl_lr'] = fut.Close.rolling(window=w,closed="left").apply(lambda y: 
                           np.poly1d(np.polyfit(np.array(range(w)),y,1))(w),raw=True)

        fut['Cl2'] = fut.Close.rolling(window=2,closed="left").apply(lambda y: 
                           np.poly1d(np.polyfit([0,1],y,1))(2),raw=True)

        rho = np.corrcoef(fut.Close[-len(xd):],fut.Cl_lr[-len(xd):])
        ph_df = fut[["Close","Cl_lr",'Cl2']][w:len(STOCK)].reset_index()
        ph_df.rename(columns={'Close': 'y', 'Date': 'ds'}, inplace=True)

        m = Prophet(holidays=holidays,
                    daily_seasonality=False,
                    changepoint_prior_scale=0.015)
        m.add_seasonality(name='monthly', period=25.5, fourier_order=5)
        m.add_regressor('Cl_lr')
        m.add_regressor('Cl2')
        m.fit(ph_df)
        # Predict Prices
        future_prices = m.make_future_dataframe(periods=175, freq='d')
        future_prices = future_prices[future_prices.ds.dt.dayofweek < 5]
        future_prices = future_prices.set_index("ds").join(fut[['Cl_lr','Cl2']][w:], how='left')
        
        future_prices = future_prices.reset_index()   
        forecast = m.predict(future_prices)
        result = TEST[['Close']].join(forecast.set_index("ds"),how='left')
        result=result[['yhat']]
        result=result.rename(columns = {"yhat": df.columns[i]}, inplace=True)
        result=result.reset_index()
        prophet_result=pd.merge(prophet_result,result)
        print(f'----------------{df.columns[i]}is done------------------')
# Out:
# Initial log joint probability = -2.29617
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       993.267    0.00082545        320.53      0.3791      0.8459      121
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      176       994.748   0.000197923        290.66   6.732e-07       0.001      246  LS failed, Hessian reset
#      199       994.795   2.80017e-06       251.298      0.8731      0.8731      275
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      247       994.798     1.389e-08       210.769      0.4133           1      335
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -3.36734
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       78       981.257   0.000374309        314.61   1.176e-06       0.001      143  LS failed, Hessian reset
#       99       981.512   9.46924e-06       198.542           1           1      171
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      162       981.837   0.000249786       249.658   8.253e-07       0.001      289  LS failed, Hessian reset
#      199       982.108   5.40514e-07       232.819      0.3903      0.3903      338
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      255       982.116   5.00673e-09       212.811       0.118       0.118      409
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -3.69714
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       827.813    0.00054293       329.631      0.5605      0.5605      128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      158       833.653    0.00070374       309.903   2.139e-06       0.001      241  LS failed, Hessian reset
#      199       833.858   2.74024e-07       267.799      0.2994           1      291
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      221       833.861   3.74035e-06       298.264   1.232e-08       0.001      362  LS failed, Hessian reset
#      247       833.863   4.88823e-09       255.222      0.3986      0.3986      398
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -3.13003
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       93       1006.84   0.000222921       386.238   4.042e-07       0.001      156  LS failed, Hessian reset
#       99       1007.08   0.000333754       357.772           1           1      162
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      139       1009.15   0.000522659       614.897   1.997e-06       0.001      256  LS failed, Hessian reset
#      197       1009.77    2.6028e-05       246.694   1.038e-07       0.001      378  LS failed, Hessian reset
#      199       1009.77   1.34727e-05       235.851           1           1      380
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      236       1009.77   9.60032e-07        250.24   3.824e-09       0.001      471  LS failed, Hessian reset
#      249       1009.77   8.74481e-09       209.357      0.7405     0.07405      492
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -3.91799
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       923.226   9.04753e-05       220.822      0.6829      0.6829      129
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199        924.22   9.65277e-05       244.274           1           1      256
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       924.306    2.5619e-05       248.058           1           1      376
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      330       924.571   0.000364923       263.441   1.316e-06       0.001      473  LS failed, Hessian reset
#      375        924.63   7.40504e-09       202.722      0.4707      0.4707      533
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -3.4363
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1000.95   0.000710572       243.727           1           1      137
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      102       1001.06   0.000176073       295.277   6.938e-07       0.001      171  LS failed, Hessian reset
#      199        1001.3   0.000315886       158.498      0.1971      0.6105      298
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      200       1001.31   0.000154475       254.565   9.746e-07       0.001      345  LS failed, Hessian reset
#      252       1001.43   3.20171e-05       294.442   1.337e-07       0.001      453  LS failed, Hessian reset
#      299       1001.44   1.62422e-05       153.824      0.6986      0.6986      510
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      316       1001.45    1.6141e-05       263.731   5.625e-08       0.001      569  LS failed, Hessian reset
#      399       1001.47   2.30359e-05       232.728      0.7146      0.7146      673
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       1001.75   0.000266008       262.399      0.4187           1      797
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      516       1001.97   0.000208199       339.204   6.622e-07       0.001      869  LS failed, Hessian reset
#      573       1002.02   3.72662e-06       234.735   1.707e-08       0.001      976  LS failed, Hessian reset
#      598       1002.02   3.88025e-09       203.656      0.1135      0.3337     1007
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.56962
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       78       1001.28   0.000101796       231.699   4.477e-07       0.001      148  LS failed, Hessian reset
#       99        1001.3   1.80174e-05       243.321           1           1      177
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      101       1001.31   1.07077e-05       157.902   4.844e-08       0.001      225  LS failed, Hessian reset
#      129       1001.31   9.13812e-09       204.792      0.1286      0.1286      262
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.23956
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99        1018.9   1.90943e-07       273.109      0.3131      0.8073      135
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      110        1018.9   2.58676e-09       298.156      0.1811      0.1811      151
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -4.34175
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       992.267    0.00242388       733.143      0.9989      0.9989      124
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      164       999.221   0.000192773       324.406   4.118e-07       0.001      234  LS failed, Hessian reset
#      199       999.379    1.1808e-06       253.984      0.3701      0.3701      275
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      212       999.386   2.36038e-05       267.047   8.414e-08       0.001      330  LS failed, Hessian reset
#      240       999.391   9.94549e-07       243.566   3.348e-09       0.001      404  LS failed, Hessian reset
#      250       999.391   7.10429e-09        193.71      0.2439      0.2439      418
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -4.30116
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       75       965.878   0.000463883         287.3   2.027e-06       0.001      133  LS failed, Hessian reset
#       99       965.959   5.28754e-05       293.329           1           1      163
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      108       966.066   7.72603e-05       230.051   3.379e-07       0.001      210  LS failed, Hessian reset
#      199       966.152   2.57221e-06       269.033      0.2859           1      337
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      205       966.153   9.09442e-06       193.275   4.348e-08       0.001      383  LS failed, Hessian reset
#      234       966.153   9.88226e-08       176.634   3.976e-10       0.001      464  LS failed, Hessian reset
#      238       966.153   5.29941e-09       180.692      0.2975      0.9006      469
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.7209
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       996.301    0.00218219       386.851           1           1      131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      138       996.664   4.66519e-05       297.712   1.602e-07       0.001      214  LS failed, Hessian reset
#      199       996.688   1.12875e-06       303.204       0.911       0.911      297
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299        996.76   0.000748026        369.59           1           1      417
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      319       996.905   8.81613e-05       310.991    3.01e-07       0.001      478  LS failed, Hessian reset
#      399       996.984   1.89837e-07       230.688      0.8318      0.8318      583
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      407       996.984   6.13765e-09       270.614      0.2363      0.2363      594
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -4.56455
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       985.118   6.64967e-05        235.75      0.6501      0.6501      125
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      121        985.45   0.000198027       411.462   4.145e-07       0.001      185  LS failed, Hessian reset
#      199       985.665   7.11357e-05       264.269   2.575e-07       0.001      331  LS failed, Hessian reset
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      242         985.7   4.79182e-05       281.824   1.615e-07       0.001      424  LS failed, Hessian reset
#      279       985.711   9.19396e-09       259.774      0.2908      0.2908      471
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -10.5202
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       916.256    0.00152905       294.441           1           1      119
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      104       916.648   0.000698966       413.154   1.935e-06       0.001      162  LS failed, Hessian reset
#      163       916.858   2.31465e-06       253.852   9.461e-09       0.001      273  LS failed, Hessian reset
#      186       916.858    5.9822e-09        275.92       0.524       0.524      301
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -3.36082
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1002.65   0.000375802       268.163           1           1      118
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      178       1002.89   4.54003e-05       261.005   2.016e-07       0.001      258  LS failed, Hessian reset
#      199        1002.9    7.1422e-07       221.898           1           1      286
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      238       1002.91   1.38455e-06       254.282   6.397e-09       0.001      384  LS failed, Hessian reset
#      273       1002.91   9.72188e-09       180.814      0.5456      0.5456      427
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -4.19858
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       981.575    0.00316854        407.29           1           1      128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      121        983.72   0.000637167       684.051   1.878e-06       0.001      203  LS failed, Hessian reset
#      136       984.647    0.00032991       369.064   1.133e-06       0.001      254  LS failed, Hessian reset
#      165       984.865   5.64897e-05       185.715   2.375e-07       0.001      328  LS failed, Hessian reset
#      199       984.876   5.30983e-08       190.779      0.2145      0.2145      376
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      219       984.879   1.00073e-05       199.402   4.606e-08       0.001      446  LS failed, Hessian reset
#      260        984.88   5.89061e-09       183.567      0.1792      0.1792      509
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.95423
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       998.726   0.000162732       206.982           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      144       998.748   1.77272e-06       251.073   7.747e-09       0.001      231  LS failed, Hessian reset
#      158       998.748   9.64314e-09       201.424      0.2274      0.2274      254
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -3.56727
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       70       939.607   0.000348764        274.63   1.449e-06       0.001      127  LS failed, Hessian reset
#       99       939.713   6.55436e-05       250.129      0.9259      0.9259      165
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      106       939.794   0.000550629       374.531   1.999e-06       0.001      205  LS failed, Hessian reset
#      144        939.87   3.54354e-09       265.759   0.0001962           1      264
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -3.93921
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       79         983.7   0.000118433       285.985   4.029e-07       0.001      141  LS failed, Hessian reset
#       99       983.747   2.47147e-06       283.157           1           1      170
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      161       983.863   0.000159233       324.631   4.829e-07       0.001      289  LS failed, Hessian reset
#      199       983.921   2.49194e-05       258.687           1           1      337
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      250       983.926   1.51201e-08       255.893      0.2698           1      405
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -2.26196
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1031.68    0.00210012       353.088      0.3901           1      119
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199        1037.1   5.18553e-05       251.004      0.6731      0.6731      248
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       1037.22   3.48997e-06        291.75     0.05734     0.05734      370
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      395       1037.25   6.46589e-09       249.337      0.3014      0.3014      494
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -4.38098
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       976.993    0.00205379       375.543       1.308      0.2838      129
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      180       979.036   6.88937e-05       305.188   2.324e-07       0.001      265  LS failed, Hessian reset
#      199        979.05   1.47858e-05       238.136      0.4639           1      293
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       979.263   1.77077e-06       215.106           1           1      429
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      309       979.266   1.88972e-06       266.483   6.603e-09       0.001      483  LS failed, Hessian reset
#      342       979.266   6.02913e-09       241.351      0.3275      0.3275      524
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.36993
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       995.421   0.000669737       403.092      0.5745      0.5745      128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      115       997.512   0.000221613       445.917   5.358e-07       0.001      182  LS failed, Hessian reset
#      165       1002.04    0.00111116       771.265    2.54e-06       0.001      276  LS failed, Hessian reset
#      199       1003.45   0.000358971       228.249           1           1      321
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      254       1004.07   3.53566e-05       329.777   1.431e-07       0.001      426  LS failed, Hessian reset
#      294       1004.07   8.25094e-09       215.769      0.5383      0.5383      475
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.8199
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1003.87   2.01968e-05        278.75      0.4392           1      133
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      125       1003.88   1.41492e-06       182.768   7.084e-09       0.001      208  LS failed, Hessian reset
#      151       1003.88   2.78879e-08       170.944      0.6672      0.6672      242
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -4.46987
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       961.178   0.000832184       329.598      0.3328           1      129
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       962.154    0.00147451       361.607           1           1      260
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      203       962.311   0.000195081       256.275   5.331e-07       0.001      304  LS failed, Hessian reset
#      268       962.515   2.38951e-05       239.778   8.798e-08       0.001      421  LS failed, Hessian reset
#      299       962.521   8.95649e-07       227.824      0.4707      0.4707      464
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      316       962.521   2.31217e-08       226.949      0.2555           1      490
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -2.30603
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1107.68   2.16187e-05       261.723           1           1      138
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      193       1107.73   2.22327e-06       311.025   8.518e-09       0.001      301  LS failed, Hessian reset
#      199       1107.73   3.61434e-07       316.185       0.944       0.944      308
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      218       1107.73   4.32821e-09       326.593      0.2479      0.2479      330
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -3.18438
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1026.98    0.00868826       336.573           1           1      133
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      126       1028.83   0.000200812       342.726   8.868e-07       0.001      210  LS failed, Hessian reset
#      171        1030.6    0.00012902       285.118   4.727e-07       0.001      301  LS failed, Hessian reset
#      199       1030.98   8.96772e-05       236.071      0.4732      0.4732      331
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      269       1031.37   5.29174e-05       274.232   1.954e-07       0.001      455  LS failed, Hessian reset
#      299       1031.38   3.02136e-07       232.638       2.905      0.7551      497
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       1031.43   1.63628e-05       230.196      0.3281      0.3281      618
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      484       1031.47      1.01e-06       239.859   5.152e-09       0.001      763  LS failed, Hessian reset
#      499       1031.48   9.51874e-07       202.554      0.5573      0.5573      781
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      526       1031.48   8.34589e-09       217.698      0.1451      0.1451      820
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.55696
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1091.05   0.000154856       318.692      0.3426      0.7277      129
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      117       1091.19   0.000139768       356.918   3.832e-07       0.001      190  LS failed, Hessian reset
#      179       1091.24   1.33217e-06       297.105   4.727e-09       0.001      312  LS failed, Hessian reset
#      199       1091.24   6.35599e-08       277.362      0.8027      0.8027      337
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      214       1091.24   1.55673e-08       227.702      0.6906      0.6906      355
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -2.30844
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99        1086.2   5.01628e-06       208.535      0.2693      0.7986      145
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      163       1086.21   5.27571e-09       231.449      0.2109      0.5892      227
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.59583
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99        1056.4   0.000358948       267.681      0.8937      0.8937      121
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      112        1056.9   0.000119195       337.244   3.037e-07       0.001      183  LS failed, Hessian reset
#      146       1057.07   2.62172e-06       270.912   1.082e-08       0.001      265  LS failed, Hessian reset
#      176       1057.08   2.16448e-08       217.548      0.4894           1      302
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -8.5924
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       685.383    2.8266e-06       206.116   1.292e-08       0.001      169  LS failed, Hessian reset
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      117       685.383   2.55709e-08       190.538      0.2941           1      196
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -2.6655
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       97       885.452   0.000113189       317.185   3.332e-07       0.001      180  LS failed, Hessian reset
#       99       885.467   7.64834e-05       325.626           1           1      182
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      139       885.482   6.82297e-09       283.363      0.3548      0.3548      233
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -3.11829
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99        921.43    0.00377505       393.707           1           1      134
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      145       921.904   3.80752e-06       206.392    1.87e-08       0.001      239  LS failed, Hessian reset
#      171       921.905   7.68264e-09       208.557      0.1798      0.1798      278
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -6.92105
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       702.628   6.28545e-05       232.518      0.4403      0.4403      133
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      135       702.659   9.12752e-06       252.628   3.514e-08       0.001      231  LS failed, Hessian reset
#      161       702.661    2.1762e-09       244.907     0.06257     0.06257      265
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -5.03676
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       886.336   1.34742e-05       272.638      0.2065      0.2065      129
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      145        886.38    2.3945e-07       234.028   1.045e-09       0.001      226  LS failed, Hessian reset
#      151        886.38   7.24433e-09       212.937      0.2953      0.9969      236
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.302
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1122.44   0.000170128       350.714      0.7513      0.7513      113
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      125       1123.53   0.000106492       388.427   2.276e-07       0.001      185  LS failed, Hessian reset
#      170       1123.81   1.39749e-05       219.523   6.586e-08       0.001      277  LS failed, Hessian reset
#      199       1123.82     4.637e-06       254.932           1           1      316
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      202       1123.82   8.69373e-07        248.08   3.309e-09       0.001      360  LS failed, Hessian reset
#      216       1123.82   4.87953e-09       201.996      0.1152      0.1152      379
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.37179
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1053.91   0.000836171       429.678           1           1      129
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      190       1062.28   0.000201506       512.559   4.523e-07       0.001      282  LS failed, Hessian reset
#      199       1062.57    0.00011024       223.458      0.7037      0.7037      291
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      251       1062.71   7.73084e-05       237.788   2.559e-07       0.001      403  LS failed, Hessian reset
#      299       1062.73   2.59736e-06       309.385      0.5853      0.5853      467
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      367       1062.75   1.58305e-06       261.835   6.806e-09       0.001      595  LS failed, Hessian reset
#      399       1062.75   3.18845e-07       232.637      0.2387           1      634
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      419       1062.75   5.34084e-08        222.68       1.543       0.446      662
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -3.22345
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       995.738    0.00580542       557.138           1           1      133
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       999.453   0.000729946       272.252      0.5247      0.5247      252
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      279       999.705   2.81367e-05        294.44   1.091e-07       0.001      384  LS failed, Hessian reset
#      299       999.715   9.43874e-07       209.723           1           1      409
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      316       999.715   8.23886e-09       262.812      0.6701      0.6701      431
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.79781
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       63       1037.86   0.000517785       567.947   2.259e-06       0.001      126  LS failed, Hessian reset
#       99       1039.22   0.000252504       269.326           1           1      176
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      107       1039.58    0.00111509       578.853    5.06e-06       0.001      221  LS failed, Hessian reset
#      199       1040.12   8.51429e-05       237.009      0.9072      0.9072      350
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      223       1040.31   0.000110922       280.057   4.742e-07       0.001      441  LS failed, Hessian reset
#      285       1040.37   2.79828e-05       236.383   2.212e-07       0.001      573  LS failed, Hessian reset
#      299       1040.37   7.41449e-06       254.958           1           1      591
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      372       1040.37   2.00876e-07       127.628   1.173e-09       0.001      747  LS failed, Hessian reset
#      375       1040.37   2.24139e-08       143.644           1           1      751
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -2.17518
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1120.47    0.00905357       961.106           1           1      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      183       1124.63   0.000180057       622.467   5.609e-07       0.001      261  LS failed, Hessian reset
#      199        1124.7   8.39787e-06       227.578      0.5042      0.5042      281
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      245       1124.71   8.26058e-05       216.624   2.734e-07       0.001      380  LS failed, Hessian reset
#      299       1124.72   3.04772e-08       238.052       0.332           1      459
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -3.51704
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       994.965    0.00123466       414.737           1           1      133
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      189       1006.41   0.000359353       600.228   1.022e-06       0.001      292  LS failed, Hessian reset
#      199       1007.95   0.000606641        207.98      0.4434           1      304
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      256       1008.16   6.09736e-05       199.879   3.735e-07       0.001      437  LS failed, Hessian reset
#      269       1008.17   1.41593e-06       116.204    1.09e-08       0.001      500  LS failed, Hessian reset
#      271       1008.17   1.90412e-07        133.79   2.332e-09       0.001      543  LS failed, Hessian reset
#      276       1008.17   8.49626e-09       133.751      0.0874      0.0874      551
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.10806
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1068.14   8.30108e-05       316.197      0.7969      0.7969      132
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      115       1069.05   0.000312658       386.776   8.511e-07       0.001      193  LS failed, Hessian reset
#      155       1069.88   0.000343979        328.41    1.06e-06       0.001      295  LS failed, Hessian reset
#      199          1070   1.25273e-06       284.096      0.6099      0.6099      348
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      208       1070.05   0.000109522       336.782   2.277e-07       0.001      403  LS failed, Hessian reset
#      257       1070.07    5.5424e-06       226.715   1.648e-08       0.001      505  LS failed, Hessian reset
#      291       1070.07   9.65322e-10       243.857     0.03659     0.03659      557
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.36678
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       998.854   0.000163914       307.533      0.5626      0.5626      135
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      149       999.567   7.65517e-06       277.862   2.983e-08       0.001      229  LS failed, Hessian reset
#      199       999.572   1.86611e-06       247.733      0.3356           1      298
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      204       999.577   1.47306e-05       227.949   5.699e-08       0.001      344  LS failed, Hessian reset
#      263       999.581   4.03963e-08       263.565      0.9659      0.9659      421
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -2.67727
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       93        1044.4    0.00021425       485.776   5.377e-07       0.001      159  LS failed, Hessian reset
#       99       1044.85    0.00102116       438.564           1           1      166
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      150       1046.73   0.000196104       438.251    5.31e-07       0.001      267  LS failed, Hessian reset
#      199        1046.9   7.34042e-07       281.259      0.3095           1      334
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      246       1046.91   1.51627e-06        270.09   5.547e-09       0.001      427  LS failed, Hessian reset
#      263       1046.91   4.18694e-09        293.67      0.1791      0.1791      449
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.40456
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1088.77    0.00151078       262.798           1           1      120
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      173       1089.21   5.17745e-06       277.381   2.255e-08       0.001      264  LS failed, Hessian reset
#      199       1089.21   4.05833e-07        262.54           1           1      296
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      228       1089.21   8.30739e-09       250.931      0.3849      0.3849      333
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -7.51434
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1000.97   0.000864814       292.022       0.265           1      121
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      159       1001.09   4.28992e-09       260.028      0.3765      0.3765      211
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -3.02028
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1041.16    0.00658663       558.973           1           1      128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1050.33   0.000419818       289.524      0.7751      0.7751      259
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      223       1051.58   0.000139636       381.161   3.208e-07       0.001      327  LS failed, Hessian reset
#      299       1051.82   9.18885e-07       292.538      0.6023      0.6023      427
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      344       1051.82   1.18449e-07       287.004   3.978e-10       0.001      534  LS failed, Hessian reset
#      350       1051.82   8.77117e-09       238.011      0.1458           1      542
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -3.55294
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       975.918   3.89825e-06       230.044      0.2556           1      131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      115       975.994   0.000243712       324.176   7.321e-07       0.001      198  LS failed, Hessian reset
#      191        976.06   1.36106e-08       189.411      0.1732           1      298
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -2.32583
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99        1058.3   0.000770421       349.213           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      109       1058.75   0.000229616       515.656    7.62e-07       0.001      176  LS failed, Hessian reset
#      199       1059.19   6.24042e-05       222.885           1           1      291
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      201       1059.19   7.34973e-06       267.229   3.287e-08       0.001      335  LS failed, Hessian reset
#      299       1059.28   5.74195e-06       219.523      0.3002           1      472
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      336       1059.28   4.79322e-07       219.934    1.66e-09       0.001      561  LS failed, Hessian reset
#      351       1059.28   1.56668e-08       246.155      0.1606           1      581
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -3.04721
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1084.86   0.000875364       460.539           1           1      131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      139       1086.82    0.00043156       732.129   1.427e-06       0.001      235  LS failed, Hessian reset
#      171       1088.14   0.000152333        329.36   7.916e-07       0.001      308  LS failed, Hessian reset
#      199       1088.19   3.66187e-06       226.273      0.4957           1      346
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      213       1088.26   0.000222298       254.614   7.906e-07       0.001      402  LS failed, Hessian reset
#      269        1088.3   4.32877e-09        232.85        0.22        0.22      485
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.15843
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1086.45   0.000986943       287.622           1           1      126
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1087.25   1.84135e-05       282.923      0.6891      0.6891      257
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      242       1087.28   1.34174e-06       169.743   6.074e-09       0.001      353  LS failed, Hessian reset
#      289       1087.28   4.78036e-07       210.063   1.774e-09       0.001      454  LS failed, Hessian reset
#      299       1087.28   1.67239e-07       209.079      0.2311           1      467
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      327       1087.28   9.98264e-09       176.382      0.2199           1      509
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -3.64265
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1026.57   0.000155747       262.603           1           1      120
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1028.98    0.00177485       318.137           1           1      244
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299        1029.1   3.97317e-06       221.848       2.478     0.02478      375
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      306        1029.1   4.38283e-06       264.756   1.863e-08       0.001      423  LS failed, Hessian reset
#      362        1029.1   5.95872e-09       208.908     0.02855      0.4735      500
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.19645
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1127.63    0.00286298       611.397           1           1      118
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      136       1130.32    0.00016943       601.711   1.974e-07       0.001      199  LS failed, Hessian reset
#      199       1132.06   0.000134478       323.335           1           1      283
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      204       1132.46    0.00014856       587.722    2.34e-07       0.001      324  LS failed, Hessian reset
# ...
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -2.57399
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1029.21    0.00174688       419.113           1           1      126
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      152       1034.69   0.000116919       247.144   2.182e-07       0.001      243  LS failed, Hessian reset
#      199       1036.02   0.000417615       281.844           1           1      300
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      262       1037.23   0.000219233       373.573   8.193e-07       0.001      425  LS failed, Hessian reset
#      299       1037.31   1.39384e-05       229.592      0.8581      0.8581      477
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      337       1037.32   4.90297e-06       213.211   1.977e-08       0.001      568  LS failed, Hessian reset
#      393       1037.32   1.97161e-06       252.251   6.855e-09       0.001      681  LS failed, Hessian reset
#      399       1037.32   7.80253e-06       249.687           1           1      689
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      417       1037.32   4.95908e-09       185.408     0.07283           1      717
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -3.16681
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1065.46   0.000743264       310.443           1           1      132
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      195       1073.07   7.08581e-05        213.61   3.118e-07       0.001      291  LS failed, Hessian reset
#      199       1073.08   2.21118e-05         179.3           1           1      297
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      226       1073.08   6.39325e-06       206.359   2.445e-08       0.001      378  LS failed, Hessian reset
#      263       1073.08   2.42365e-08       206.783      0.2038           1      441
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -2.26836
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1143.14   0.000152859       286.294           1           1      131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      177       1143.91   4.08089e-06         281.5   1.718e-08       0.001      265  LS failed, Hessian reset
#      199       1143.92   2.98822e-07       270.823           1           1      292
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      226       1143.92   2.52532e-08        288.84       0.223           1      328
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -3.4412
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1019.04    2.2022e-05       211.003       0.587       0.587      132
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      118       1019.18   0.000255108       416.974   7.349e-07       0.001      199  LS failed, Hessian reset
#      147       1019.29   2.63922e-05        242.05   9.201e-08       0.001      268  LS failed, Hessian reset
#      199       1019.32   7.59098e-05       213.248      0.7621      0.7621      335
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      208       1019.69   0.000307617       452.613   9.142e-07       0.001      395  LS failed, Hessian reset
#      278       1019.88   3.78295e-09       247.471      0.1127      0.1127      495
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.25332
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       92       1015.44   0.000818304       428.282   3.349e-06       0.001      154  LS failed, Hessian reset
#       99       1015.58   8.34328e-05       189.621      0.3347           1      163
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      161       1015.81   0.000178467       179.758   8.176e-07       0.001      267  LS failed, Hessian reset
#      199       1015.86   8.46728e-06       143.606           1           1      316
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       1015.93   1.43394e-06       224.129      0.6639      0.6639      436
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       1015.95   8.07122e-05       215.914           1           1      550
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      457       1016.02   0.000130514       272.013   4.742e-07       0.001      657  LS failed, Hessian reset
#      499       1016.04   9.49364e-07       264.583      0.3318           1      713
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       1016.05   1.48879e-05       204.889      0.7598           1      836
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      614       1016.05   2.72521e-08       178.474       0.256           1      863
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -5.84837
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1017.96     0.0218548       963.737           1           1      125
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1019.33     9.566e-06       289.524      0.4926      0.4926      260
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      223       1019.35   3.53344e-05       264.446   1.524e-07       0.001      340  LS failed, Hessian reset
#      249       1019.36   7.95142e-09       220.674     0.01387      0.3454      378
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -6.81092
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       967.505     0.0082082       534.793       0.238           1      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      165       969.074   0.000190481       344.496   6.534e-07       0.001      250  LS failed, Hessian reset
#      199       969.106   6.58018e-07       251.655      0.6782      0.6782      292
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      238       969.108   6.45656e-06       262.305   2.245e-08       0.001      381  LS failed, Hessian reset
#      263       969.109   8.36078e-09       281.424      0.5418      0.5418      419
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.52046
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1021.75    0.00670632       428.345           1           1      118
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      138          1026   0.000200316       395.894   3.271e-07       0.001      197  LS failed, Hessian reset
#      199       1027.89   0.000844808       529.945      0.5258      0.5258      272
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      201       1028.07   0.000183278       416.601   3.388e-07       0.001      325  LS failed, Hessian reset
#      236       1028.62   4.05683e-05        259.64   1.754e-07       0.001      403  LS failed, Hessian reset
#      298       1028.63   4.16222e-06       218.415   1.433e-08       0.001      523  LS failed, Hessian reset
#      299       1028.63   2.74387e-06       216.033           1           1      524
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      345       1028.64   3.98151e-09       262.054      0.1999      0.1999      586
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.77611
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1050.32    0.00259205       651.616           1           1      120
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      111       1051.64   0.000119037        298.83   2.669e-07       0.001      175  LS failed, Hessian reset
#      168        1054.3   0.000499481        714.94   1.742e-06       0.001      298  LS failed, Hessian reset
#      199       1055.01   5.48611e-06       211.608      0.4516      0.4516      342
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      249       1055.02   7.50286e-07       192.407   2.596e-09       0.001      467  LS failed, Hessian reset
#      255       1055.02    1.6413e-09       208.242     0.03427     0.03427      476
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.88727
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1018.18   2.77343e-06       198.475      0.2426      0.2426      135
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1018.53   7.74863e-05         157.9      0.5041      0.5041      265
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      243       1018.72   0.000116925        327.13   5.323e-07       0.001      397  LS failed, Hessian reset
#      286       1018.74    8.5106e-06       257.091   3.389e-08       0.001      488  LS failed, Hessian reset
#      299       1018.74   1.05202e-06       207.664           1           1      509
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      318       1018.74    3.4363e-09       216.831     0.06495           1      537
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -2.47866
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1080.62    0.00116109       230.846           1           1      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      120        1082.5   0.000348505       751.084   8.432e-07       0.001      187  LS failed, Hessian reset
#      177       1083.93   0.000145524       345.526   1.758e-07       0.001      320  LS failed, Hessian reset
#      199       1084.57   0.000307321        299.22      0.8556      0.8556      348
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      231       1084.71   4.70585e-05       283.815   2.175e-07       0.001      432  LS failed, Hessian reset
#      299       1084.73   3.98027e-07       265.548      0.6191      0.6191      522
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      313       1084.73   2.18774e-08       200.235      0.3105           1      550
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -2.10894
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1269.35    0.00106845        498.94           1           1      116
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1271.94   0.000292067       414.233      0.8171      0.8171      241
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      273       1272.47   0.000101206       604.679   3.706e-07       0.001      384  LS failed, Hessian reset
#      299       1272.59   1.68375e-05        242.39           1           1      417
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      306        1272.6   3.66455e-05       391.811     1.5e-07       0.001      473  LS failed, Hessian reset
#      399       1272.63   5.83849e-06       252.016           1           1      591
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      437       1272.64   2.71445e-06       234.701   1.432e-08       0.001      706  LS failed, Hessian reset
#      499       1272.64   1.13959e-06       270.217      0.4954      0.4954      783
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      545       1272.64   1.42869e-08       209.449     0.08248     0.08248      838
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# --------------
# Initial log joint probability = -2.18164
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       93       1165.71   0.000248897       653.474   5.725e-07       0.001      152  LS failed, Hessian reset
#       99        1165.9   4.98033e-05       273.089      0.2469      0.2469      159
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199        1167.2    6.7181e-05        244.24           1           1      275
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      238        1167.2   9.84935e-09       253.056      0.6916      0.6916      324
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------
# Initial log joint probability = -5.61993
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       984.037    0.00178749       267.579      0.7154      0.7154      119
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      151       988.055   0.000266261       428.952   3.825e-07       0.001      221  LS failed, Hessian reset
#      199       988.568   2.30202e-07       221.898       0.222           1      286
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      228       988.574   3.67595e-06       242.601   1.534e-08       0.001      361  LS failed, Hessian reset
#      299       988.578   7.22456e-08       250.276      0.9452      0.9452      448
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      301       988.578   5.57288e-09       231.204      0.1722      0.1722      451
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# --------------

# %%
prophet_result
# Out:
#          Date         1301    7246pred     7250pred    7254pred     7259pred  \
# 0  2021-12-06  3039.315357  388.971374  1150.256153  483.756237  4255.126205
# 1  2021-12-07  2999.969707  388.726765  1133.642008  504.338266  4190.859796
# 2  2021-12-08  3090.926833  392.259961  1167.932325  527.934930  4410.821225
# 3  2021-12-09  3094.448575  395.163714  1171.441020  535.462482  4503.355634
# 4  2021-12-10  3098.764267  394.779020  1128.202669  516.370867  4342.298392
# ..        ...          ...         ...          ...         ...          ...
# 90 2022-04-19  3151.567827  372.678769   941.338641  488.431952  3765.923338
# 91 2022-04-20  3145.792102  379.640403   947.502848  494.992112  3887.606363
# 92 2022-04-21  3216.566367  383.129738   978.490908  494.284008  4047.066414
# 93 2022-04-22  3258.423068  387.201397   976.966934  502.914152  4023.024931
# 94 2022-04-25  3233.443645  383.290224   958.286523  478.625406  3893.303634
#
#        7261pred     7267pred     7269pred     7270pred  ...     9982pred  \
# 0    956.860926  3241.868636  4676.799071  2095.537872  ...  1761.039850
# 1    931.753005  3216.766014  4573.594646  2069.955791  ...  1800.393830
# 2    977.438904  3298.267796  4732.740331  2154.563967  ...  1796.107566
# 3    983.456225  3273.346373  4803.113716  2181.679295  ...  1780.014804
# 4    950.609226  3212.969027  4670.771149  2150.378033  ...  1771.492686
# ..          ...          ...          ...          ...  ...          ...
# 90   915.954936  3220.829675  4141.514253  1914.368404  ...  1316.335304
# 91   970.865454  3275.485616  4232.363104  1968.368297  ...  1300.686298
# 92  1004.324417  3411.781458  4362.297330  2068.868486  ...  1294.885367
# 93   980.043085  3397.284700  4399.309423  2084.206003  ...  1292.086174
# 94   951.489087  3319.715746  4281.736060  2054.857448  ...  1286.453278
#
#         9983pred     9984pred     9987pred     9989pred    9990pred  \
# 0   67612.613238  5401.693048  3209.389293  3090.121002  534.528979
# 1   69091.843795  5036.841236  3171.588472  3175.690259  524.236303
# 2   68820.340665  5383.196695  3238.957288  3192.440906  540.372279
# 3   69380.046135  5767.983444  3254.022608  3198.266384  548.553747
# 4   68693.891260  5588.329291  3324.483538  3116.613476  549.436388
# ..           ...          ...          ...          ...         ...
# 90  66146.146321  5448.737948  3597.143801  2835.788260  478.592282
# 91  62157.925126  5233.552613  3588.623214  2759.679956  491.912527
# 92  64740.925458  5355.915880  3693.989821  2916.203812  490.320409
# 93  67151.551265  5405.771262  3696.849768  2995.236381  499.975026
# 94  64298.162216  5243.456036  3620.901038  2944.181485  490.635305
#
#       9991pred     9993pred     9994pred    9997pred
# 0   819.332362  1658.143663  2428.942012  693.257410
# 1   802.690790  1648.866363  2448.384130  704.894301
# 2   809.437379  1644.312397  2465.893620  721.143824
# 3   816.768738  1669.404354  2446.819518  745.129151
# 4   808.091652  1675.006425  2431.391192  728.293278
# ..         ...          ...          ...         ...
# 90  775.528511  1559.189814  2441.829081  681.513630
# 91  775.154426  1564.208038  2451.806414  677.746362
# 92  778.845735  1592.817458  2457.090922  696.905411
# 93  786.704129  1608.696826  2475.692373  696.160524
# 94  797.368453  1593.199153  2470.049668  677.000095
#
# [95 rows x 670 columns]

# %%
def absHighPass(df, absThresh):
    df.loc[:, ]
    passed = set()
    for (r,c) in combinations(df.columns, 2):
        if (abs(df.loc[r,c]) >= absThresh):
            passed.add(r)
            passed.add(c)
    passed = sorted(passed)
    return df.loc[passed,passed]

corr = df.corr()

# %%
mat = absHighPass(corr,0.978)
mask = np.triu(np.ones_like(mat))
fig, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(mat, annot=True, mask=mask, cmap="viridis")
plt.show()

# %%
fig = sns.PairGrid(df[[9101, 9104, 9107, 9110, 6532]].dropna())
fig.map_upper(plt.scatter, color='blue')
fig.map_lower(sns.kdeplot, cmap='cool_d')
fig.map_diag(sns.distplot, bins=30);

# %%
cols = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'SecuritiesCode', 'Target']
STOCK = df_train[df_train.SecuritiesCode==Code][cols].set_index("Date")
TEST = df_test[df_test.SecuritiesCode==Code].set_index("Date")
display_html(STOCK)

# %%
STOCK

# %%
TEST

# %%
plt.figure(figsize=(15,7))
plt.title("Plot a Histogram of the Daily Closing Price - TRAIN set")
sns.distplot(STOCK['Close'].dropna(), bins=50, color='blue');

# %%
plt.figure(figsize=(15,7))
plt.title("Plot a Histogram of the Daily Closing Price - TEST set")
sns.distplot(TEST['Close'].dropna(), bins=50, color='magenta');

# %%
STOCK=STOCK.reset_index()
STOCK['Date']=pd.to_datetime(STOCK['Date'])
STOCK

# %%
STOCK=STOCK.set_index('Date')
STOCK

# %%
TEST

# %%
plt.figure(figsize=(15,7))
top = plt.subplot2grid((4,4), (0, 0), rowspan=3, colspan=4)
bottom = plt.subplot2grid((4,4), (3,0), rowspan=1, colspan=4)
top.plot(STOCK.index, STOCK.Close, label="Train set")
top.plot(TEST.index,TEST.Close, color="magenta", label="Test set")
bottom.bar(STOCK.index, STOCK.Volume)
bottom.bar(TEST.index, TEST.Volume, color="magenta")
top.legend(bbox_to_anchor=(1.01, 1., 0.11, 0.), loc='upper right', borderaxespad=0.)
 
# set the labels
top.axes.xaxis.set_ticklabels([])
top.axvline(TEST.index[0], color='red', linestyle='--')
bottom.axvline(TEST.index[0], color='red', linestyle='--')
top.set_title(Code)
top.grid(True)
top.set_ylabel('Closing Price')
bottom.set_ylabel('Volume')
bottom.grid(True);

# %%
df_test

# %%
d = 287
# days to plot
e = 15  # days to extrapolate
g = 2  # max degree of regression

width = .8
width2 = .1
col1 = 'green'
col2 = 'red'

LDAYS = STOCK.head(d)
up = LDAYS[LDAYS.Close>=LDAYS.Open]
down = LDAYS[LDAYS.Close<LDAYS.Open]
fut = TEST[:]


xd = (LDAYS.index).append(TEST.head(e).index)

x = [x for x in range(d)]
p = {}
for i in range(g):
    z = np.polyfit(x, LDAYS.Close, i+1)
    p[i] = np.poly1d(z)
x = np.array(range(d+e))

plt.figure(figsize=(15,7))
top = plt.subplot2grid((4,4), (0, 0), rowspan=3, colspan=4)
top.set_title(f"CandleStick Chart of last {d} days with {e} extrapolated days by polynomials of degrees until {g}")
top.axes.xaxis.set_ticklabels([])
for i in range(g):
    top.plot(xd, p[i](x), linewidth=1, label=f'Degree {i+1}')
top.plot(fut.index,fut.Close,  marker="o", markersize=5, color="magenta", linewidth=0, label="Test Close")
top.bar(up.index,up.Close-up.Open,width,bottom=up.Open,color=col1)
top.bar(up.index,up.High-up.Close,width2,bottom=up.Close,color=col1)
top.bar(up.index,up.Low-up.Open,width2,bottom=up.Open,color=col1)
top.bar(down.index,down.Close-down.Open,width,bottom=down.Open,color=col2)
top.bar(down.index,down.High-down.Open,width2,bottom=down.Open,color=col2)
top.bar(down.index,down.Low-down.Close,width2,bottom=down.Close,color=col2)
top.axvline(TEST.index[0], color='red', linestyle='--')
top.legend(bbox_to_anchor=(1.01, 1., 0.11, 0.), loc='upper right', borderaxespad=0.)
top.grid(True)

bottom = plt.subplot2grid((4,4), (3,0), rowspan=1, colspan=4)
bottom.bar(xd, np.append(LDAYS['Volume'].values,np.zeros(e))) 
bottom.bar(fut.index, fut.Volume, color="magenta") 
bottom.axvline(TEST.index[0], color='red', linestyle='--')

bottom.grid(True)
plt.show();

# %%
fut

# %%
TEST

# %%
d = 365 # days to plot
w = 3 # windows size

LDAYS = STOCK.tail(d)
fut = pd.concat([STOCK,TEST])
xd = (LDAYS.index).append(TEST.index)

fut['Cl_lr'] = fut.Close.rolling(window=w,closed="left").apply(lambda y: 
                   np.poly1d(np.polyfit(np.array(range(w)),y,1))(w),raw=True)

fut['Cl2'] = fut.Close.rolling(window=2,closed="left").apply(lambda y: 
                   np.poly1d(np.polyfit([0,1],y,1))(2),raw=True)

rho = np.corrcoef(fut.Close[-len(xd):],fut.Cl_lr[-len(xd):])

plt.figure(figsize=(15,7))
plt.plot(LDAYS.index, LDAYS.Close, label="Train set")
plt.plot(TEST.index,TEST.Close, color="magenta", label="Test set")
plt.plot(xd,fut.Cl_lr[-len(xd):], color="black", label="Rolling LR")
plt.axvline(TEST.index[0], color='red', linestyle='--')
plt.title(f"Rolling Liner Regression with {w}-days window - Pearson Correlation = {rho[0,1]:.3f}")
plt.legend(bbox_to_anchor=(1.01, 1., 0.11, 0.), loc='upper right', borderaxespad=0.)
plt.show();

# %%
# Generate diagonal line to plot.
fig, ax = plt.subplots(figsize=(8,8))
d_x = np.linspace(start=TEST.Close.min() - 1, stop=TEST.Close.max() + 1, num=100)
sns.regplot(x=TEST.Close, y=fut.Cl_lr[-len(TEST):], color='magenta', label='test', ax=ax)
sns.lineplot(x=d_x, y=d_x, dashes={'linestyle': ''}, color='blue', ax=ax)
ax.lines[1].set_linestyle('--')
ax.set(title=f'Test Data vs Predictions - Corr = {np.corrcoef(TEST.Close,fut.Cl_lr[-len(TEST):])[0,1]:.3f}');

# %%
# Generate diagonal line to plot.
rho = np.corrcoef(result.Close,result.yhat)
fig, ax = plt.subplots(figsize=(8,8))
d_x = np.linspace(start=TEST.Close.min() - 1, stop=TEST.Close.max() + 1, num=175)
sns.regplot(x=result.Close, y=result.yhat, color='magenta', label='test', ax=ax)
sns.lineplot(x=d_x, y=d_x, dashes={'linestyle': ''}, color='blue', ax=ax)
ax.lines[1].set_linestyle('--')
ax.legend(loc='upper left')
ax.set(title=f'Test Data vs Predictions - Corr = {np.corrcoef(result.Close,result.yhat)[0,1]:.3f}');

# %%
fig = m.plot(forecast)
plt.title(f"{Code} Stock Price Forecast", fontsize=16)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Close Price", fontsize=12)
plt.axvline(TEST.index[0], color='red', linestyle='--')
plt.plot(TEST.index, TEST.Close,  marker="o", markersize=3, color="magenta", linewidth=0, label="Test Close")
plt.show()

# %%
fig2 = m.plot_components(forecast)
plt.show()

# %%
forecast.columns

# %%
df
# Out:
# SecuritiesCode    1301   1332    1333    1375    1376    1377    1379    1381  \
# Date
# 2020-10-05      2819.0  453.0  2412.0  2062.0  1615.0  3775.0  2238.0  3330.0
# 2020-10-06      2824.0  450.0  2398.0  2044.0  1588.0  3785.0  2236.0  3355.0
# 2020-10-07      2780.0  446.0  2345.0  2035.0  1541.0  3730.0  2243.0  3300.0
# 2020-10-08      2786.0  443.0  2345.0  2035.0  1502.0  3800.0  2254.0  3250.0
# 2020-10-09      2799.0  436.0  2336.0  2099.0  1510.0  3745.0  2244.0  3300.0
# ...                ...    ...     ...     ...     ...     ...     ...     ...
# 2021-11-29      2951.0  567.0  2269.0  1248.0  1381.0  3125.0  1889.0  3160.0
# 2021-11-30      2900.0  573.0  2277.0  1217.0  1348.0  3125.0  1842.0  3135.0
# 2021-12-01      2911.0  574.0  2299.0  1231.0  1353.0  3135.0  1889.0  3185.0
# 2021-12-02      2933.0  573.0  2303.0  1212.0  1327.0  3110.0  1867.0  3150.0
# 2021-12-03      2982.0  585.0  2358.0  1235.0  1332.0  3170.0  1891.0  3200.0
#
# SecuritiesCode    1407    1413  ...    9982     9983    9984    9987    9989  \
# Date                            ...
# 2020-10-05      2133.8  1978.0  ...  1799.0  66790.0  6750.0  3980.0  4010.0
# 2020-10-06      2203.1  1988.0  ...  1829.0  66700.0  6913.0  4060.0  3985.0
# 2020-10-07      2237.7  1990.0  ...  1868.0  66490.0  6955.0  3980.0  3940.0
# 2020-10-08      2330.8  1976.0  ...  1862.0  67290.0  7085.0  4025.0  4045.0
# 2020-10-09      2469.2  1989.0  ...  1711.0  69220.0  6997.0  4020.0  4080.0
# ...                ...     ...  ...     ...      ...     ...     ...     ...
# 2021-11-29      6430.0  2126.0  ...  1725.0  70500.0  6208.0  3070.0  3055.0
# 2021-11-30      6550.0  2118.0  ...  1690.0  67400.0  6030.0  3085.0  2989.0
# 2021-12-01      6290.0  2123.0  ...  1722.0  67080.0  5900.0  3090.0  2937.0
# 2021-12-02      6070.0  2112.0  ...  1680.0  67140.0  5599.0  3105.0  2947.0
# 2021-12-03      6190.0  2197.0  ...  1746.0  66650.0  5559.0  3175.0  3015.0
#
# SecuritiesCode   9990   9991    9993    9994   9997
# Date
# 2020-10-05      571.0  951.0  1794.0  2169.0  934.0
# 2020-10-06      573.0  952.0  1788.0  2185.0  943.0
# 2020-10-07      569.0  932.0  1808.0  2185.0  960.0
# 2020-10-08      568.0  944.0  1824.0  2195.0  953.0
# 2020-10-09      569.0  934.0  1840.0  2169.0  958.0
# ...               ...    ...     ...     ...    ...
# 2021-11-29      528.0  773.0  1680.0  2358.0  668.0
# 2021-11-30      520.0  768.0  1680.0  2328.0  667.0
# 2021-12-01      522.0  770.0  1671.0  2340.0  685.0
# 2021-12-02      507.0  778.0  1650.0  2362.0  684.0
# 2021-12-03      528.0  794.0  1645.0  2389.0  696.0
#
# [287 rows x 2000 columns]

# %%
pd.concat(df[1301],prophet_result.set_index('Date')['1301'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_33/4179083990.py in <module>
# ----> 1 pd.concat(df[1301],prophet_result.set_index('Date')['1301'])
#
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     302         verify_integrity=verify_integrity,
#     303         copy=copy,
# --> 304         sort=sort,
#     305     )
#     306
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     328         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
#     329             raise TypeError(
# --> 330                 "first argument must be an iterable of pandas "
#     331                 f'objects, you passed an object of type "{type(objs).__name__}"'
#     332             )
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "Series"

# %%
prophet_result = prophet_result.pivot(index='Date', columns='SecuritiesCode', values='Close')
prophet_result

# %%
# Utilities 

def calc_spread_return_per_day(df, portfolio_size, toprank_weight_ratio):
    weights = np.linspace(start=toprank_weight_ratio, stop=1, num=portfolio_size)
    weights_mean = weights.mean()
    df = df.sort_values(by='Rank')
    purchase = (df['Target'][:portfolio_size]  * weights).sum() / weights_mean
    short    = (df['Target'][-portfolio_size:] * weights[::-1]).sum() / weights_mean
    return purchase - short

def calc_spread_return_sharpe(df, portfolio_size=200, toprank_weight_ratio=2):
    grp = df.groupby('Date')
    min_size = grp["Target"].count().min()
    if min_size<2*portfolio_size:
        portfolio_size=min_size//2
        if portfolio_size<1:
            return 0, None
    buf = grp.apply(calc_spread_return_per_day, portfolio_size, toprank_weight_ratio)
    sharpe_ratio = buf.mean() / buf.std()
    return sharpe_ratio, buf
def add_rank(df, col_name="pred"):
    df["Rank"] = df.groupby("Date")[col_name].rank(ascending=False, method="first") - 1 
    df["Rank"] = df["Rank"].astype("int")
    return df

# %%
# sns.set_style("whitegrid")
# sns.set(rc={'figure.figsize':(15.7,6)})

# def getadvance(x):
#     ret = 0
#     if x > 0:
#         ret = 1
#     return(ret)

# def get_month(dt):
#     x = dt.strftime("%m")
#     return(x)

# def RSI(series, period):
#     delta = series.diff().dropna()
#     u = delta * 0
#     d = u.copy()
#     u[delta > 0] = delta[delta > 0]
#     d[delta < 0] = -delta[delta < 0]
#     u[u.index[period-1]] = np.mean( u[:period] ) #first value is sum of avg gains
#     u = u.drop(u.index[:(period-1)])
#     d[d.index[period-1]] = np.mean( d[:period] ) #first value is sum of avg losses
#     d = d.drop(d.index[:(period-1)])
#     rs = pd.DataFrame.ewm(u, com=period-1, adjust=False).mean() / \
#          pd.DataFrame.ewm(d, com=period-1, adjust=False).mean()
#     return 100 - 100 / (1 + rs)

# def rsi_class(x):
#     ret = "low"
#     if x < 50:
#         ret = "low"
#     if x > 50:
#         ret = "med"
#     if x > 70:
#         ret = "hi"
#     return(ret)
# # os.listdir('../input/jpx-tokyo-stock-exchange-prediction/train_files/')
# def display_dataframe(df, title = ""):
#     #tdstring = f'<td style="text-align: left; vertical-align: middle; font-size:1.2em;">{v}</td>'
#     if (title != ""):
#         text = f'<h2>{title}</h2><table><tr>'
#     else:
#         text = '<table><tr>'
#     text += ''.join([f'<td style="text-align: left; vertical-align: middle; font-size:1.2em;"><b>{col}</b></td>' for col in df.columns.values]) + '</tr>'
#     for row in df.itertuples():
#         #text +=  '<tr>' + ''.join([f'<td valign="top">{v}</td>' for v in row[1:]]) + '</tr>'
#         text +=  '<tr>' + ''.join([ f'<td style="text-align: left; vertical-align: middle; font-size:1.1em;">{v}</td>' for v in row[1:]]) + '</tr>'
#     text += '</table>'
#     display(HTML(text))
    
# def prep_prices(price, test = False):
#     from decimal import ROUND_HALF_UP, Decimal
#     pcols = ["Open","High","Low","Close"]
#     price.ExpectedDividend.fillna(0,inplace=True)
#     def qround(x):
#         return float(Decimal(str(x)).quantize(Decimal('0.1'), rounding=ROUND_HALF_UP))
    
#     def adjust_prices(df):
#         df = df.sort_values("Date", ascending=False)
#         df.loc[:, "CumAdjust"] = df["AdjustmentFactor"].cumprod()

#         # generate adjusted prices
#         for p in pcols:     
#             df.loc[:, p] = (df["CumAdjust"] * df[p]).apply(qround)
#         df.loc[:, "Volume"] = df["Volume"] / df["CumAdjust"]
#         df.ffill(inplace=True)
#         df.bfill(inplace=True)
        
#         # generate and fill Targets
#         #df.loc[:, "Target"] = ((df.Close.shift(-2)/df.Close.shift(-1) - 1)).fillna(df.Target)
#         if (not test):
#             df.Target.fillna(0,inplace=True)

#         return df

#     # generate Adjusted
#     price = price.sort_values(["SecuritiesCode", "Date"])
#     price = price.groupby("SecuritiesCode").apply(adjust_prices).reset_index(drop=True)
#     price = price.sort_values("RowId")
#     return price

# %%
def add_feat(df):
    df['C4'] = df.Close.rolling(window=4,closed="left").apply(lambda y: 
               np.poly1d(np.polyfit([0,1,2,3],y,1))(4),raw=True)     
    df['C3'] = df.Close.rolling(window=3,closed="left").apply(lambda y: 
               np.poly1d(np.polyfit([0,1,2],y,1))(3),raw=True)        
    df['C2'] = df.Close.rolling(window=2,closed="left").apply(lambda y: 
               np.poly1d(np.polyfit([0,1],y,1))(2),raw=True)
    return df

def run_prophet(tr):
    m = Prophet(holidays=holidays,
                daily_seasonality='auto',
                yearly_seasonality='auto',
                weekly_seasonality='auto',
                changepoint_prior_scale=0.1)
    m.add_regressor('C4')
    m.add_regressor('C3')
    m.add_regressor('C2')
    m.fit(tr)
    pred = m.predict(tr[-2:])
    return (pred.yhat[1]/pred.yhat[0] - 1)

def run_reg(tr):
    pred = list(0.6*tr.C2[-2:]+0.4*tr.C3[-2:])
    return (pred[1]/pred[0] - 1)
def proc_cod(cod, tr):
    tr = tr[tr.SecuritiesCode==cod][["Date","Close"]]
    x = [0,1]
    for _ in x:
        tr = tr.append(
        pd.DataFrame({'Date': pd.date_range(start=tr.Date.iloc[-1], 
                                            periods=2, freq='B', 
                                            closed='right'),
                      'Close': np.poly1d(np.polyfit(x,tr.Close[-2:],1))(2)
                     })
        )
    tr = add_feat(tr)
    tr = tr[6:]
    target = run_reg(tr)
    return target

# %%
prices
# Out:
#                 RowId        Date  SecuritiesCode    Open    High     Low  \
# 0       20211206_1301  2021-12-06            1301  2982.0  2982.0  2965.0
# 1       20211206_1332  2021-12-06            1332   592.0   599.0   588.0
# 2       20211206_1333  2021-12-06            1333  2368.0  2388.0  2360.0
# 3       20211206_1375  2021-12-06            1375  1230.0  1239.0  1224.0
# 4       20211206_1376  2021-12-06            1376  1339.0  1372.0  1339.0
# ...               ...         ...             ...     ...     ...     ...
# 229953  20220527_9990  2022-05-27            9990   560.0   577.0   559.0
# 229954  20220527_9991  2022-05-27            9991   819.0   819.0   804.0
# 229955  20220527_9993  2022-05-27            9993  1505.0  1513.0  1505.0
# 229956  20220527_9994  2022-05-27            9994  2430.0  2496.0  2430.0
# 229957  20220527_9997  2022-05-27            9997   655.0   656.0   649.0
#
#          Close   Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag  \
# 0       2971.0     8900               1.0               NaN            False
# 1        589.0  1360800               1.0               NaN            False
# 2       2377.0   125900               1.0               NaN            False
# 3       1224.0    81100               1.0               NaN            False
# 4       1351.0     6200               1.0               NaN            False
# ...        ...      ...               ...               ...              ...
# 229953   577.0   153200               1.0               NaN            False
# 229954   819.0    18100               1.0               NaN            False
# 229955  1513.0     2000               1.0               NaN            False
# 229956  2483.0    15700               1.0               NaN            False
# 229957   651.0   141100               1.0               NaN            False
#
#           Target
# 0      -0.003263
# 1      -0.008993
# 2      -0.009963
# 3      -0.015032
# 4       0.002867
# ...          ...
# 229953  0.003378
# 229954 -0.005995
# 229955  0.009315
# 229956 -0.013540
# 229957  0.000000
#
# [229958 rows x 12 columns]

# %%
add_feat(df_test)

# %%
tr = df_test[df_test.Date==prices.Date.iat[0]].copy()
tr
# run_prophet(tr)

# %%
import jpx_tokyo_market_prediction
env = jpx_tokyo_market_prediction.make_env()
iter_test = env.iter_test()

# %%
supplemental_stock_prices = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/supplemental_files/stock_prices.csv")
supplemental_stock_prices

# %%
supplemental_stock_prices["Rank"] = supplemental_stock_prices.groupby("Date")["Target"].rank(ascending=False,method="first") -1
supplemental_stock_prices.tail(3)

# %%
finday = supplemental_stock_prices[supplemental_stock_prices["Date"]=="2022-05-27"].reset_index(drop=True)
finday

# %%
finday[finday["Rank"]==finday["Rank"].iloc[0]]
finday["Rank"] = finday["Rank"].astype("int")

# %%
counter = 0
# The API will deliver six dataframes in this specific order:
for (prices, options, financials, trades, secondary_prices, sample_prediction) in iter_test:
    if counter == 0:
        print(prices.head())
        print(options.head())
        print(financials.head())
        print(trades.head())
        print(secondary_prices.head())
        print(sample_prediction.head())
    sample_prediction['Rank'] = np.arange(len(sample_prediction))
    env.predict(sample_prediction)
    counter += 1

# %%
findaydict = dict(zip(finday["SecuritiesCode"],finday["Rank"]))
findaydict

# %%
sample_prediction.head(3)

# %%
sample_prediction["Rank"]  = sample_prediction["SecuritiesCode"].map(findaydict)
sample_prediction

# %%
df_train

# %%
# %%time


trgts = {}
for (prices,options, financials, trades, sample_prediction) in iter_test:
    cods = prices.SecuritiesCode.unique()
    df_train = pd.concat([df_train, prices])
    df_train = df_train.sort_values(["SecuritiesCode", "Date"])
    df_train.ffill(inplace=True)
    for cod in tqdm(cods):
        trgts[cod] = proc_cod(cod, df_train)
    tr = df_train[df_train.Date==prices.Date.iat[0]].copy()
    tr.Target=tr["SecuritiesCode"].map(trgts) 
    tr = add_rank(tr, "Target")
    score = calc_spread_return_per_day(tr,200,2)
    print(f"Score: {score}")
    pred = tr.set_index("SecuritiesCode")["Rank"]
    sample_prediction['Rank'] = sample_prediction["SecuritiesCode"].map(pred)
    env.predict(sample_prediction)

# %%
tr

# %%
trgts

# %%
df_train

# %%
# # advance to decline ratio in a month
# sns.set(rc={'figure.figsize':(14.7,3)})
# sns.set_style("whitegrid")
# seclist = [1301, 1332, 1333, 1376, 1377]
# for SECURITY in seclist:
# #seclist = [1301]
# #SECURITY = 1301
#     df_c = df_prices.copy()
#     df_stock = df_c[df_c['SecuritiesCode']== SECURITY].reset_index()
#     df_stock = df_stock.sort_values(by = "Date", ascending = False)
#     df_stock['pClose'] = df_stock['Close'].shift(-1)
#     df_stock['delta'] = df_stock['Close'] - df_stock['pClose']
#     df_stock['advance'] = list(map(getadvance, df_stock['delta']))
#     df_stock['Date'] = pd.to_datetime(df_stock['Date'], format = "%Y-%m-%d")
#     df_stock['Month'] =  list(map(get_month, df_stock['Date']))
#     df_stats = df_stock.groupby(["Month"]).agg(
#                         advances = ("advance", "sum"), total = ("advance",  "count")).reset_index()
#     df_stats['advance_to_decline'] = df_stats['advances'] / (df_stats['total'] - df_stats['advances'])
#     plt.title(f"Examining advance to decline ratio for:{SECURITY}")
#     ax  = sns.barplot(x="Month", y="advance_to_decline", data=df_stats, palette="Blues_d")
#     plt.show()

# %%
# sns.set_style("whitegrid")
# SECURITY = 1301
# df_stock = df_prices[df_prices['SecuritiesCode'] == SECURITY].reset_index(drop = True)
# df_stock = df_stock.sort_values(by = "Date").reset_index()
# df_stock['rsi'] = RSI( df_stock['Close'], 14 )
# df_stock['rsicat'] = list(map(rsi_class, df_stock['rsi']))
# fig, (ax1, ax2, ax3) = plt.subplots(3,1, figsize = (12,8))
# fig.subplots_adjust(hspace=0.5)
# ax1.plot(df_stock.index, df_stock['Close']);
# labels = [item.get_text() for item in ax1.get_xticklabels()]
# ax1.set_xticklabels(labels)
# ax2.plot(df_stock.index, df_stock['Volume']);
# labels = [item.get_text() for item in ax2.get_xticklabels()]
# ax2.set_xticklabels(labels)
# ax3.plot(df_stock.index, df_stock['rsi']);
# labels = [item.get_text() for item in ax3.get_xticklabels()]
# ax3.set_xticklabels(labels)
# plt.suptitle(f"Comparing Price Close, Volume and RSI for security:{SECURITY}")
# plt.tight_layout()

# %%
# # Utilities 

# def calc_spread_return_per_day(df, portfolio_size, toprank_weight_ratio):
#     weights = np.linspace(start=toprank_weight_ratio, stop=1, num=portfolio_size)
#     weights_mean = weights.mean()
#     df = df.sort_values(by='Rank')
#     purchase = (df['Target'][:portfolio_size]  * weights).sum() / weights_mean
#     short    = (df['Target'][-portfolio_size:] * weights[::-1]).sum() / weights_mean
#     return purchase - short

# def calc_spread_return_sharpe(df, portfolio_size=200, toprank_weight_ratio=2):
#     grp = df.groupby('Date')
#     min_size = grp["Target"].count().min()
#     if min_size<2*portfolio_size:
#         portfolio_size=min_size//2
#         if portfolio_size<1:
#             return 0, None
#     buf = grp.apply(calc_spread_return_per_day, portfolio_size, toprank_weight_ratio)
#     sharpe_ratio = buf.mean() / buf.std()
#     return sharpe_ratio, buf

# def add_rank(df, col_name="pred"):
#     df["Rank"] = df.groupby("Date")[col_name].rank(ascending=False, method="first") - 1 
#     df["Rank"] = df["Rank"].astype("int")
#     return df

# %%
# ## By Yuike - https://www.kaggle.com/code/ikeppyo/examples-of-higher-scores-than-perfect-predictions

# # This function adjusts the predictions so that the daily spread return approaches a certain value.
# # 측정을 위한 단위 만드는 함수        
# def adjuster(df):
#     def calc_pred(df, x, y, z):
        
#         return df['Target'].where(df['Target'].abs() < x, df['Target'] * y + np.sign(df['Target']) * z)

#     def objective(trial, df):
#         x = trial.suggest_uniform('x', 0, 0.2)
#         y = trial.suggest_uniform('y', 0, 0.05)
#         z = trial.suggest_uniform('z', 0, 1e-3)
#         df["Rank"] = calc_pred(df, x, y, z).rank(ascending=False, method="first") - 1 
#         return calc_spread_return_per_day(df, 200, 2)

#     def predictor_per_day(df):
#         study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=SD))#5187
#         study.optimize(lambda trial: abs(objective(trial, df) - 3), 3)
#         return calc_pred(df, *study.best_params.values())

#     return df.groupby("Date").apply(predictor_per_day).reset_index(level=0, drop=True)

# def _predictor_base(feature_df):
#     return model.predict(feature_df[feats])

# def _predictor_with_adjuster(feature_df):
#     df_pred = feature_df.copy()
#     df_pred["Target"] = model.predict(feature_df[feats])
#     return adjuster(df_pred).values.T

# %%
# # Close는 종가가격/ Target은 수익율
# np.random.seed(0)
# feats = ["Close"]
# max_score = 0
# max_depth = 0
# for md in tqdm(range(3,40)):
#     model = DecisionTreeRegressor( max_depth=md ) # Controlling the overfit with max_depth parameter
#     model.fit(df_prices[feats],df_prices["Target"])
#     predictor = _predictor_base
#     prices["pred"] = predictor(prices)
#     score, buf = calc_spread_return_sharpe(add_rank(prices))
#     if score>max_score:
#         max_score = score
#         max_depth = md
        
# model = DecisionTreeRegressor( max_depth=max_depth )
# model.fit(df_prices[feats],df_prices["Target"])
# print(f'Max_deph={max_depth} : Sharpe Ratio Score base -> {max_score}')

# %%
# # Controlling the Sharpe Ratio Score (≃3)
# predictor = _predictor_with_adjuster
# err = 1
# maxSD = 3770
# for SD in tqdm(range(maxSD,5000)):
#     prices["pred"] = predictor(prices)
#     score, buf = calc_spread_return_sharpe(add_rank(prices))
#     if abs(score-3)<=err and score<3:
#         err=abs(score-3)
#         maxSD = SD
#         print(f'{maxSD} Sharpe Ratio Score with adjuster -> {score}')
        
# SD = maxSD

# %%
# %%time
# env = jpx_tokyo_market_prediction.make_env()
# iter_test = env.iter_test()

# for prices, options, financials, trades, secondary_prices, sample_prediction in iter_test:
#     prices = fill_nans(prices)
#     prices.loc[:,"pred"] = predictor(prices)
#     prices = add_rank(prices)
#     rank = prices.set_index('SecuritiesCode')['Rank'].to_dict()
#     sample_prediction['Rank'] = sample_prediction['SecuritiesCode'].map(rank)
#     env.predict(sample_prediction)
